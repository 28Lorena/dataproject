# %%
import altair as alt
import pandas as pd
import numpy as np

perfume= pd.read_csv (r"C:\Users\lanzc\Documents\week5\perfume_data (1).csv")

print (perfume)
# Out:
#     Names of Perfume      1s      2s      3s  ...     25s     26s     27s     28s
# 0             ajayeb  64,558  64,556  64,543  ...  64,528  64,528  64,528  64,528
# 1              ajmal  60,502  60,489  61,485  ...  61,485  60,487  60,472  60,472
# 2             amreaj  57,040  57,040  57,040  ...  58,041  58,041  58,041  58,041
# 3               aood  71,083  72,087  71,091  ...  71,103  72,103  72,103  72,098
# 4          asgar_ali  68,209  68,209  68,216  ...  68,223  68,223  68,223  68,230
# 5            bukhoor  71,046  71,046  71,046  ...  70,046  70,046  70,048  71,048
# 6          burberrry  61,096  61,096  60,093  ...  60,089  61,088  61,088  60,089
# 7         dehenalaod  68,132  69,137  69,137  ...  69,137  69,137  69,137  69,136
# 8             junaid  71,590  71,575  71,574  ...  72,542  72,556  72,556  72,556
# 9             kausar  74,631  74,649  74,650  ...  73,585  73,585  73,585  73,585
# ...

# %%
perfume.shape
# Out:
# (20, 29)

# %%
import altair as alt
import pandas as pd
import numpy as np

perfume= pd.read_csv (r"C:\Users\lanzc\Documents\week5\perfume_data (1).csv")

perfume.head()
# Out:
#   Names of Perfume      1s      2s      3s  ...     25s     26s     27s     28s
# 0           ajayeb  64,558  64,556  64,543  ...  64,528  64,528  64,528  64,528
# 1            ajmal  60,502  60,489  61,485  ...  61,485  60,487  60,472  60,472
# 2           amreaj  57,040  57,040  57,040  ...  58,041  58,041  58,041  58,041
# 3             aood  71,083  72,087  71,091  ...  71,103  72,103  72,103  72,098
# 4        asgar_ali  68,209  68,209  68,216  ...  68,223  68,223  68,223  68,230
#
# [5 rows x 29 columns]

# %%
import altair as alt
import pandas as pd 

perfume= pd.read_csv (r"C:\Users\lanzc\Documents\week5\perfume_data (1).csv")

alt.Chart(perfume).mark_point().encode(
    x = "Names of Perfume",
    y = "1s"
)
# Out:
# alt.Chart(...)

# %%
import altair as alt
import pandas as pd 

perfume= pd.read_csv (r"C:\Users\lanzc\Documents\week5\perfume_data (1).csv")

alt.Chart(perfume).mark_line().encode(
    x = "Names of Perfume",
    y = "1s"
)
# Out:
# alt.Chart(...)

# %%
import altair as alt
import pandas as pd

perfume= pd.read_csv (r"C:\Users\lanzc\Documents\week5\perfume_data (1).csv")


y = "OMX-GR"= ("1s", "2s", "3s", "4s", "5s", "6s", "7s", "8s", "9s", "10s", "11s", "12s", "13s", "14s", 
         "15s", "16s", "17s", "18s", "19s", "20s", "21s", "22s", "23s", "24s", "25s", "26s", "27s", "28s")

alt.Chart(perfume).mark_line().encode(
    x = "Names of Perfume",
    y = "OMX-GR"
)

# %%
###

import altair as alt
import pandas as pd

df = pd.read_csv ("Swallow_Screening_List_sample.csv")

alt.Chart (df).mark_point().encode (
    x = "Swallow Screen",
    y = "Date"

)
# Out:
# alt.Chart(...)

# %%
df
# Out:
#     Date Admission Time Swallow Screen Time  Swallow Screen
# 0     29       16:00:00    29/06/2021 16:01            3.31
# 1      4       20:54:00    12/06/2021 21:00            3.29
# 2      5            NaN    05/06/2021 11:08            2.30
# 3     27       11:19:00    27/06/2021 12:54            1.54
# 4      5       14:50:00    05/06/2021 12:58            1.50
# 5     10       19:49:00    10/06/2021 17:51            1.48
# 6     28       01:44:00    28/06/2021 21:47            1.47
# 7     22       05:37:00    23/06/2021 15:45            1.45
# 8     10       16:49:00    10/06/2021 14:48            1.40
# 9     28       02:20:00    28/06/2021 19:47            1.39
# 10     9       12:57:00    09/06/2021 11:40            1.34
# 11    28            NaN    28/06/2021 06:34            1.34
# 12     2       13:47:00    02/06/2021 11:54            1.32
# 13    19            NaN    19/06/2021 12:14            1.27
# 14    15       18:24:00    15/06/2021 16:55            1.25
# ...

# %%
import altair as alt
import pandas as pd

df = pd.read_csv ("Swallow_Screening_List_sample.csv")

alt.Chart (df).mark_point().encode (
    x = "Swallow Screen",
    y = "Date"
)
# Out:
# alt.Chart(...)
